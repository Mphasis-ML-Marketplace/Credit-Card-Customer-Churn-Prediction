# %% [markdown]
# ### Credit Card Customer Churn Prediction
# Customer churn refers to the loss of existing clients or customers. This solution identifies credit card customers who are more likely to close their account and leave the Company. During the training stage, the solution automatically conducts feature interaction on the training data and selects a subset of features based on feature importance. It then trains multiple models and identifies the best performing model. This model is then selected for prediction on new data.
#
# ### Contents
#
# 1. [Set up the environment](#Set-up-the-environment)
# 1. [Usage Instructions](#Usage-Instructions)
# 1. [Upload the data for training](#Upload-the-data-for-training)
# 1. [Run Training Job](#Run-Training-Job)
# 1. [Live Inference Endpoint](#Live Inference)
# 1. [Batch Transform Job](#Batch-Transform-Job)
# 1. [Output Interpretation](#Output-Interpretation)
#
#
#
# <img src="images/Flow_diagram.JPG">

# %% [markdown]
# ### Prerequisite
#
# To run this algorithm you need to have access to the following AWS Services:
# - Access to AWS SageMaker and the model package.
# - An S3 bucket to specify input/output.
# - Role for AWS SageMaker to access input/output from S3.

# %% [markdown]
# ### Input format
# #### Input:
# Name of the file: <b>train.csv</b><br>
# This file contains historical churn prediction data for Ecommerce. T<br><br>
#
# </ul>
# <li>  Tenure:Tenure of customer in organization</li>
# <li> PreferredLoginDevice: Preferred login device of customer</li>
#
# <li> CityTier: City tier</li>
# <li> WarehouseToHome: Distance in between warehouse to home of customer</li>
# <li> PreferredPaymentMode: Preferred payment method of customer</li>
# <li> Gender: Gender of customer</li>
# <li> HourSpendOnApp: Number of hours spend on mobile application or website</li>
#
# <li> NumberOfDeviceRegistered: Total number of deceives is registered on particular customer</li>
# <li> PreferedOrderCat: Preferred order category of customer in last month</li>
# <li> SatisfactionScore: Satisfactory score of customer on service</li>
# <li> MaritalStatus: Marital status of customer</li>
# <li> NumberOfAddress: Total number of added added on particular customer
#
#  <li>Complain: Any complaint has been raised in last month</li>
# <li> OrderAmountHikeFromlastYear: Percentage increases in order from last year</li>
# <li> CouponUsed: Total number of coupon has been used in last month</li>
# <li> OrderCount: Total number of orders has been places in last month</li>
# <li> DaySinceLastOrder: Day Since last order by customer</li>

# %% [markdown]
# ## Set up the environment
# Here we specify a bucket to use and the role that will be used for working with SageMaker.

# %%
# S3 prefix
prefix = 'churn-credit card'

# Define IAM role
import boto3
import re

import os
import numpy as np
import pandas as pd
from sagemaker import get_execution_role

role = get_execution_role()

# %% [markdown]
# ## Create the session
# The session remembers our connection parameters to SageMaker. We'll use it to perform all of our SageMaker operations.

# %%
import sagemaker as sage
from time import gmtime, strftime

sess = sage.Session()

# %% [markdown]
# ## Upload the data for training
# When training large models with huge amounts of data, you'll typically use big data tools, like Amazon Athena, AWS Glue, or Amazon EMR, to create your data in S3. For the purposes of this example, we're using classification dataset, which we have included.
#
# We can use use the tools provided by the SageMaker Python SDK to upload the data to a default bucket.

# %%
data_location= 's3://mphasis-marketplace/churn-prediction-creditcard/input/train.csv'

# %% [markdown]
# ## Create an estimator and fit the model
# In order to use SageMaker to fit our algorithm, we'll create an Estimator that defines how to use the container to train. This includes the configuration we need to invoke SageMaker training:
# - The container name. This is constructed as in the shell commands above.
# - The role. As defined above.
# - The instance count which is the number of machines to use for training.
# - The instance type which is the type of machine to use for training.
# - The output path determines where the model artifact will be written.
# - The session is the SageMaker session object that we defined above
#
# Then we use fit() on the estimator to train against the data that we uploaded above.

# %%
account = sess.boto_session.client('sts').get_caller_identity()['Account']
region = sess.boto_session.region_name
image = '{}.dkr.ecr.{}.amazonaws.com/telecom-pycaret-churn'.format(account, region)

tree = sage.estimator.Estimator(image,
                       role, 3, 'ml.c4.2xlarge',
                      output_path="s3://{}/output".format(sess.default_bucket()),
                       sagemaker_session=sess)

tree.fit(data_location)
# Out:
# 2021-04-28 14:11:36 Starting - Starting the training job...
# 2021-04-28 14:11:59 Starting - Launching requested ML instancesProfilerReport-1619619096: InProgress
# ......
# 2021-04-28 14:12:59 Starting - Preparing the instances for training......
# 2021-04-28 14:13:59 Downloading - Downloading input data
# 2021-04-28 14:13:59 Training - Downloading the training image......
# 2021-04-28 14:14:59 Training - Training image download completed. Training in progress..Starting the training.
# (10000, 11)
# IntProgress(value=0, description='Processing: ', max=3)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              14:15:02
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                     14:15:02
# Status     . . . . . . . . . . . . . . . . . .  Preparing Data for Modeling
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                     14:15:02
# Status     . . . . . . . . . . . . . . . . . .  Preparing Data for Modeling
#
#
# Initiated  . . . . . . . . . . . . . . . . . .            14:15:02
# Status     . . . . . . . . . . . . . . . . . .  Preprocessing Data
#
#
# Initiated  . . . . . . . . . . . . . . . . . .            14:15:02
# Status     . . . . . . . . . . . . . . . . . .  Preprocessing Data
# Starting the training.
# (10000, 11)
# IntProgress(value=0, description='Processing: ', max=3)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              14:14:58
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                     14:14:58
# Status     . . . . . . . . . . . . . . . . . .  Preparing Data for Modeling
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                     14:14:58
# Status     . . . . . . . . . . . . . . . . . .  Preparing Data for Modeling
#
#
# Initiated  . . . . . . . . . . . . . . . . . .            14:14:58
# Status     . . . . . . . . . . . . . . . . . .  Preprocessing Data
#
#
# Initiated  . . . . . . . . . . . . . . . . . .            14:14:58
# Status     . . . . . . . . . . . . . . . . . .  Preprocessing Data
# Setup Succesfully Completed!
# #033[2K#015#033[2K#015<pandas.io.formats.style.Styler object at 0x7fecf53dba90>
# IntProgress(value=0, description='Processing: ', max=69)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              14:15:01
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .     Compiling Library
# Empty DataFrame
# Columns: [Model, Accuracy, AUC, Recall, Prec., F1, Kappa, MCC, TT (Sec)]
# Index: []
#
#
# Initiated  . . . . . . . . . . . . . . . . . .           14:15:01
# Status     . . . . . . . . . . . . . . . . . .  Loading Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Compiling Library
#
#
# Initiated  . . . . . . . . . . . . . . . . . .           14:15:01
# Status     . . . . . . . . . . . . . . . . . .  Loading Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Compiling Library
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:15:01
# Status     . . . . . . . . . . . . . . . . . .    Loading Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:15:01
# Status     . . . . . . . . . . . . . . . . . .    Loading Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:15:01
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:15:01
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:15:01
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:15:01
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:15:01
# Status     . . . . . . . . . . . . . . . . . .      Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:15:01
# Status     . . . . . . . . . . . . . . . . . .      Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:15:01
# Status     . . . . . . . . . . . . . . . . . .     Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:15:01
# Status     . . . . . . . . . . . . . . . . . .     Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
# Starting the training.
# (10000, 11)
# IntProgress(value=0, description='Processing: ', max=3)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              14:15:04
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                     14:15:04
# Status     . . . . . . . . . . . . . . . . . .  Preparing Data for Modeling
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                     14:15:04
# Status     . . . . . . . . . . . . . . . . . .  Preparing Data for Modeling
#
#
# Initiated  . . . . . . . . . . . . . . . . . .            14:15:04
# Status     . . . . . . . . . . . . . . . . . .  Preprocessing Data
#
#
# Initiated  . . . . . . . . . . . . . . . . . .            14:15:04
# Status     . . . . . . . . . . . . . . . . . .  Preprocessing Data
# Setup Succesfully Completed!
# #033[2K#015#033[2K#015<pandas.io.formats.style.Styler object at 0x7fd9657194e0>
# Setup Succesfully Completed!
# #033[2K#015#033[2K#015<pandas.io.formats.style.Styler object at 0x7f5ca27e3a20>
# IntProgress(value=0, description='Processing: ', max=69)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              14:15:07
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .     Compiling Library
# Empty DataFrame
# Columns: [Model, Accuracy, AUC, Recall, Prec., F1, Kappa, MCC, TT (Sec)]
# Index: []
#
#
# Initiated  . . . . . . . . . . . . . . . . . .           14:15:07
# Status     . . . . . . . . . . . . . . . . . .  Loading Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Compiling Library
#
#
# Initiated  . . . . . . . . . . . . . . . . . .           14:15:07
# Status     . . . . . . . . . . . . . . . . . .  Loading Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Compiling Library
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:15:07
# Status     . . . . . . . . . . . . . . . . . .    Loading Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:15:07
# Status     . . . . . . . . . . . . . . . . . .    Loading Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:15:07
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:15:07
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:15:07
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:15:07
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:15:07
# Status     . . . . . . . . . . . . . . . . . .      Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:15:07
# Status     . . . . . . . . . . . . . . . . . .      Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:15:07
# Status     . . . . . . . . . . . . . . . . . .     Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:15:07
# Status     . . . . . . . . . . . . . . . . . .     Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
# <pandas.io.formats.style.Styler object at 0x7fecf5613438>
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                14:15:01
# Status     . . . . . . . . . . . . . . . . . .        Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  K Neighbors Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                14:15:01
# Status     . . . . . . . . . . . . . . . . . .        Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  K Neighbors Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                14:15:01
# Status     . . . . . . . . . . . . . . . . . .     Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  K Neighbors Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                14:15:01
# Status     . . . . . . . . . . . . . . . . . .     Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  K Neighbors Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                14:15:01
# Status     . . . . . . . . . . . . . . . . . .     Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  K Neighbors Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                14:15:01
# Status     . . . . . . . . . . . . . . . . . .     Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  K Neighbors Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                14:15:01
# Status     . . . . . . . . . . . . . . . . . .         Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  K Neighbors Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                14:15:01
# Status     . . . . . . . . . . . . . . . . . .         Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  K Neighbors Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                14:15:01
# Status     . . . . . . . . . . . . . . . . . .        Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  K Neighbors Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                14:15:01
# Status     . . . . . . . . . . . . . . . . . .        Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  K Neighbors Classifier
# IntProgress(value=0, description='Processing: ', max=69)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              14:15:07
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .     Compiling Library
# Empty DataFrame
# Columns: [Model, Accuracy, AUC, Recall, Prec., F1, Kappa, MCC, TT (Sec)]
# Index: []
#
#
# Initiated  . . . . . . . . . . . . . . . . . .           14:15:07
# Status     . . . . . . . . . . . . . . . . . .  Loading Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Compiling Library
#
#
# Initiated  . . . . . . . . . . . . . . . . . .           14:15:07
# Status     . . . . . . . . . . . . . . . . . .  Loading Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Compiling Library
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:15:07
# Status     . . . . . . . . . . . . . . . . . .    Loading Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:15:07
# Status     . . . . . . . . . . . . . . . . . .    Loading Estimator
# <pandas.io.formats.style.Styler object at 0x7fecf5482780>
#
#
# Initiated  . . . . . . . . . . . . . . . . . .          14:15:01
# Status     . . . . . . . . . . . . . . . . . .  Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .       Naive Bayes
#
#
# Initiated  . . . . . . . . . . . . . . . . . .          14:15:01
# Status     . . . . . . . . . . . . . . . . . .  Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .       Naive Bayes
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:15:01
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .          Naive Bayes
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:15:01
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .          Naive Bayes
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:15:01
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .          Naive Bayes
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:15:01
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .          Naive Bayes
#
#
# Initiated  . . . . . . . . . . . . . . . . . .         14:15:01
# Status     . . . . . . . . . . . . . . . . . .  Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .      Naive Bayes
#
#
# Initiated  . . . . . . . . . . . . . . . . . .         14:15:01
# Status     . . . . . . . . . . . . . . . . . .  Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .      Naive Bayes
#
#
# Initiated  . . . . . . . . . . . . . . . . . .          14:15:01
# Status     . . . . . . . . . . . . . . . . . .  Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .       Naive Bayes
#
#
# Initiated  . . . . . . . . . . . . . . . . . .          14:15:01
# Status     . . . . . . . . . . . . . . . . . .  Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .       Naive Bayes
# <pandas.io.formats.style.Styler object at 0x7fecf52fa860>
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                  14:15:01
# Status     . . . . . . . . . . . . . . . . . .          Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Decision Tree Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                  14:15:01
# Status     . . . . . . . . . . . . . . . . . .          Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Decision Tree Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                  14:15:01
# Status     . . . . . . . . . . . . . . . . . .       Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Decision Tree Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                  14:15:01
# Status     . . . . . . . . . . . . . . . . . .       Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Decision Tree Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                  14:15:01
# Status     . . . . . . . . . . . . . . . . . .       Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Decision Tree Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                  14:15:01
# Status     . . . . . . . . . . . . . . . . . .       Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Decision Tree Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                  14:15:01
# Status     . . . . . . . . . . . . . . . . . .           Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  Decision Tree Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                  14:15:01
# Status     . . . . . . . . . . . . . . . . . .           Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  Decision Tree Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                  14:15:01
# Status     . . . . . . . . . . . . . . . . . .          Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Decision Tree Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                  14:15:01
# Status     . . . . . . . . . . . . . . . . . .          Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Decision Tree Classifier
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:15:07
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:15:07
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:15:07
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:15:07
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:15:07
# Status     . . . . . . . . . . . . . . . . . .      Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:15:07
# Status     . . . . . . . . . . . . . . . . . .      Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:15:07
# Status     . . . . . . . . . . . . . . . . . .     Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:15:07
# Status     . . . . . . . . . . . . . . . . . .     Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
# <pandas.io.formats.style.Styler object at 0x7fecf552f0b8>
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:15:01
# Status     . . . . . . . . . . . . . . . . . .     Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  SVM - Linear Kernel
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:15:01
# Status     . . . . . . . . . . . . . . . . . .     Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  SVM - Linear Kernel
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:15:01
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  SVM - Linear Kernel
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:15:01
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  SVM - Linear Kernel
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:15:01
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  SVM - Linear Kernel
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:15:01
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  SVM - Linear Kernel
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:15:01
# Status     . . . . . . . . . . . . . . . . . .      Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  SVM - Linear Kernel
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:15:01
# Status     . . . . . . . . . . . . . . . . . .      Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  SVM - Linear Kernel
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:15:01
# Status     . . . . . . . . . . . . . . . . . .     Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  SVM - Linear Kernel
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:15:01
# Status     . . . . . . . . . . . . . . . . . .     Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  SVM - Linear Kernel
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# <pandas.io.formats.style.Styler object at 0x7fecf5613198>
#
#
# Initiated  . . . . . . . . . . . . . . . . . .          14:15:01
# Status     . . . . . . . . . . . . . . . . . .  Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Ridge Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .          14:15:01
# Status     . . . . . . . . . . . . . . . . . .  Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Ridge Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:15:01
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .     Ridge Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:15:01
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .     Ridge Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:15:01
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .     Ridge Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:15:01
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .     Ridge Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .          14:15:01
# Status     . . . . . . . . . . . . . . . . . .   Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  Ridge Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .          14:15:01
# Status     . . . . . . . . . . . . . . . . . .   Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  Ridge Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .          14:15:01
# Status     . . . . . . . . . . . . . . . . . .  Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Ridge Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .          14:15:01
# Status     . . . . . . . . . . . . . . . . . .  Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Ridge Classifier
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=1.44158e-09): result may not be accurate.
#   overwrite_a=True).T
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=1.44779e-09): result may not be accurate.
#   overwrite_a=True).T
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=1.44122e-09): result may not be accurate.
#   overwrite_a=True).T
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=1.44039e-09): result may not be accurate.
#   overwrite_a=True).T
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=1.44722e-09): result may not be accurate.
#   overwrite_a=True).T
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=1.44623e-09): result may not be accurate.
#   overwrite_a=True).T
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=1.44302e-09): result may not be accurate.
#   overwrite_a=True).T
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=1.44768e-09): result may not be accurate.
#   overwrite_a=True).T
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=1.43923e-09): result may not be accurate.
#   overwrite_a=True).T
# <pandas.io.formats.style.Styler object at 0x7fecf53205f8>
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                  14:15:01
# Status     . . . . . . . . . . . . . . . . . .          Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Random Forest Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                  14:15:01
# Status     . . . . . . . . . . . . . . . . . .          Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Random Forest Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                  14:15:01
# ...
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         14:15:07
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         14:15:07
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         14:15:07
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         14:15:07
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         14:15:07
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         14:15:07
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         14:15:07
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         14:15:07
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         14:15:07
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         14:15:07
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         14:15:07
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         14:15:07
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         14:15:07
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         14:15:07
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         14:15:07
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         14:15:07
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         14:15:07
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         14:15:07
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         14:15:07
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         14:15:07
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         14:15:07
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         14:15:07
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
# #033[2K#015#033[2K#015<pandas.io.formats.style.Styler object at 0x7fd96592eb00>
# Transformation Pipeline and Model Succesfully Saved
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         14:15:07
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         14:15:07
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         14:15:07
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         14:15:07
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         14:15:07
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         14:15:07
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         14:15:07
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         14:15:07
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         14:15:07
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         14:15:07
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
# rf model saved
# files under /opt/ml/model  ['/opt/ml/model/model.pkl']
# model saved
# total time taken using multiprocessing is -  17.360973125
# training complete
# #033[2K#015#033[2K#015<pandas.io.formats.style.Styler object at 0x7f5ca273df60>
# Transformation Pipeline and Model Succesfully Saved
# rf model saved
# files under /opt/ml/model  ['/opt/ml/model/model.pkl']
# model saved
# total time taken using multiprocessing is -  26.408336211
# training complete
#
# 2021-04-28 14:15:59 Uploading - Uploading generated training model
# 2021-04-28 14:15:59 Completed - Training job completed
# Training seconds: 384
# Billable seconds: 384

# %% [markdown]
# ## Hosting your model
# You can use a trained model to get real time predictions using HTTP endpoint. Follow these steps to walk you through the process.

# %%
training_job_name = tree.latest_training_job.name
attached_tree = sage.estimator.Estimator.attach(training_job_name)
# Out:
# 2021-04-28 14:16:19 Starting - Preparing the instances for training
# 2021-04-28 14:16:19 Downloading - Downloading input data
# 2021-04-28 14:16:19 Training - Training image download completed. Training in progress.
# 2021-04-28 14:16:19 Uploading - Uploading generated training model
# 2021-04-28 14:16:19 Completed - Training job completed

# %% [markdown]
# ### Deploy the model
# Deploying the model to SageMaker hosting just requires a deploy call on the fitted model. This call takes an instance count, instance type, and optionally serializer and deserializer functions. These are used when the resulting predictor is created on the endpoint.

# %%
from sagemaker.predictor import csv_serializer
predictor = attached_tree.deploy(4, 'ml.m4.xlarge', serializer=csv_serializer,endpoint_name='churn-creditcard-pycaret')
# Out:
# -------------!

# %% [markdown]
# ## Choose some data and use it for a prediction

# %%
test_data  = 's3://mphasis-marketplace/churn-prediction-creditcard/input/test.csv'

data = pd.read_csv(test_data,encoding='ISO-8859–1',header=None)
data
# Out:
#              0          1       2    3       4          5              6  \
# 0  CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts
# 1          619     France  Female   42       2          0              1
# 2          608      Spain  Female   41       1   83807.86              1
# 3          502     France  Female   42       8   159660.8              3
# 4          699     France  Female   39       1          0              2
# 5          850      Spain  Female   43       2  125510.82              1
#
#            7               8                9
# 0  HasCrCard  IsActiveMember  EstimatedSalary
# 1          1               1        101348.88
# 2          0               1        112542.58
# 3          1               0        113931.57
# 4          0               0         93826.63
# 5          1               1          79084.1

# %%
predictions = predictor.predict(data.values).decode('utf-8')
# Out:
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %%
print(predictions)
# Out:
# CreditScore,Geography,Gender,Age,Tenure,Balance,NumOfProducts,HasCrCard,IsActiveMember,EstimatedSalary,Label,Score
# 619,France,Female,42,2,0.0,1,1,1,101348.88,1,0.5371
# 608,Spain,Female,41,1,83807.86,1,0,1,112542.58,0,0.8849
# 502,France,Female,42,8,159660.8,3,1,0,113931.57,0,0.679
# 699,France,Female,39,1,0.0,2,0,0,93826.63,0,0.9468
# 850,Spain,Female,43,2,125510.82,1,1,1,79084.1,0,0.9484

# %% [markdown]
# ### Output
#
# Output files contains column predicted Group, which has the predicted class

# %%
transform_output_folder = "batch-transform-output"
output_path="s3://{}/{}".format(sess.default_bucket(), transform_output_folder)

transformer = tree.transformer(instance_count=1,
                               instance_type='ml.m4.xlarge',
                               output_path=output_path)

# %%
transformer.transform(test_data, content_type='text/csv')
transformer.wait()
print("Batch Transform output saved to " + transformer.output_path)
# Out:
# .............................Starting the inference server with 4 workers.
# [2021-04-28 14:35:31 +0000] [13] [INFO] Starting gunicorn 20.1.0
# [2021-04-28 14:35:31 +0000] [13] [INFO] Listening at: unix:/tmp/gunicorn.sock (13)
# [2021-04-28 14:35:31 +0000] [13] [INFO] Using worker: gevent
# [2021-04-28 14:35:31 +0000] [17] [INFO] Booting worker with pid: 17
# [2021-04-28 14:35:31 +0000] [18] [INFO] Booting worker with pid: 18
# [2021-04-28 14:35:31 +0000] [19] [INFO] Booting worker with pid: 19
# [2021-04-28 14:35:31 +0000] [20] [INFO] Booting worker with pid: 20
# Transformation Pipeline and Model Successfully Loaded
# 169.254.255.130 - - [28/Apr/2021:14:35:39 +0000] "GET /ping HTTP/1.1" 200 1 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [28/Apr/2021:14:35:39 +0000] "GET /execution-parameters HTTP/1.1" 404 2 "-" "Go-http-client/1.1"
# Transformation Pipeline and Model Successfully Loaded
# 169.254.255.130 - - [28/Apr/2021:14:35:40 +0000] "POST /invocations HTTP/1.1" 200 385 "-" "Go-http-client/1.1"
#
# 2021-04-28T14:35:39.572:[sagemaker logs]: MaxConcurrentTransforms=1, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD
# Starting the inference server with 4 workers.
# [2021-04-28 14:35:31 +0000] [13] [INFO] Starting gunicorn 20.1.0
# [2021-04-28 14:35:31 +0000] [13] [INFO] Listening at: unix:/tmp/gunicorn.sock (13)
# [2021-04-28 14:35:31 +0000] [13] [INFO] Using worker: gevent
# Starting the inference server with 4 workers.
# [2021-04-28 14:35:31 +0000] [13] [INFO] Starting gunicorn 20.1.0
# [2021-04-28 14:35:31 +0000] [13] [INFO] Listening at: unix:/tmp/gunicorn.sock (13)
# [2021-04-28 14:35:31 +0000] [13] [INFO] Using worker: gevent
# [2021-04-28 14:35:31 +0000] [17] [INFO] Booting worker with pid: 17
# [2021-04-28 14:35:31 +0000] [18] [INFO] Booting worker with pid: 18
# [2021-04-28 14:35:31 +0000] [19] [INFO] Booting worker with pid: 19
# [2021-04-28 14:35:31 +0000] [20] [INFO] Booting worker with pid: 20
# [2021-04-28 14:35:31 +0000] [17] [INFO] Booting worker with pid: 17
# [2021-04-28 14:35:31 +0000] [18] [INFO] Booting worker with pid: 18
# [2021-04-28 14:35:31 +0000] [19] [INFO] Booting worker with pid: 19
# [2021-04-28 14:35:31 +0000] [20] [INFO] Booting worker with pid: 20
# Transformation Pipeline and Model Successfully Loaded
# 169.254.255.130 - - [28/Apr/2021:14:35:39 +0000] "GET /ping HTTP/1.1" 200 1 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [28/Apr/2021:14:35:39 +0000] "GET /execution-parameters HTTP/1.1" 404 2 "-" "Go-http-client/1.1"
# Transformation Pipeline and Model Successfully Loaded
# Transformation Pipeline and Model Successfully Loaded
# 169.254.255.130 - - [28/Apr/2021:14:35:39 +0000] "GET /ping HTTP/1.1" 200 1 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [28/Apr/2021:14:35:39 +0000] "GET /execution-parameters HTTP/1.1" 404 2 "-" "Go-http-client/1.1"
# Transformation Pipeline and Model Successfully Loaded
# 169.254.255.130 - - [28/Apr/2021:14:35:40 +0000] "POST /invocations HTTP/1.1" 200 385 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [28/Apr/2021:14:35:40 +0000] "POST /invocations HTTP/1.1" 200 385 "-" "Go-http-client/1.1"
# 2021-04-28T14:35:39.572:[sagemaker logs]: MaxConcurrentTransforms=1, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD
# Batch Transform output saved to s3://sagemaker-us-east-2-786796469737/batch-transform-output

# %% [markdown]
# #### Inspect the Batch Transform Output in S3

# %%
from urllib.parse import urlparse

parsed_url = urlparse(transformer.output_path)
bucket_name = parsed_url.netloc
file_key = '{}/{}.out'.format(parsed_url.path[1:], "test.csv")



s3_client = sess.boto_session.client('s3')

response = s3_client.get_object(Bucket = sess.default_bucket(), Key = file_key)
response_bytes = response['Body'].read().decode('utf-8')
print(response_bytes)
# Out:
# CreditScore,Geography,Gender,Age,Tenure,Balance,NumOfProducts,HasCrCard,IsActiveMember,EstimatedSalary,Label,Score
# 619,France,Female,42,2,0.0,1,1,1,101348.88,1,0.5371
# 608,Spain,Female,41,1,83807.86,1,0,1,112542.58,0,0.8849
# 502,France,Female,42,8,159660.8,3,1,0,113931.57,0,0.679
# 699,France,Female,39,1,0.0,2,0,0,93826.63,0,0.9468
# 850,Spain,Female,43,2,125510.82,1,1,1,79084.1,0,0.9484

# %% [markdown]
# ### View Output
# Lets read results of above transform job from s3 files and print output

# %%
s3_client = sess.boto_session.client('s3')
s3_client.download_file(sess.default_bucket(), "{}/test.csv.out".format(transform_output_folder), '/tmp/test.csv.out')
with open('/tmp/test.csv.out') as f:
    results = f.readlines() 
##print("Transform results: \n{}".format(''.join(results)))
string_final = ''.join(results)

print(string_final)

with open("Output.txt", "w") as text_file:
    text_file.write(string_final)
# Out:
# CreditScore,Geography,Gender,Age,Tenure,Balance,NumOfProducts,HasCrCard,IsActiveMember,EstimatedSalary,Label,Score
# 619,France,Female,42,2,0.0,1,1,1,101348.88,1,0.5371
# 608,Spain,Female,41,1,83807.86,1,0,1,112542.58,0,0.8849
# 502,France,Female,42,8,159660.8,3,1,0,113931.57,0,0.679
# 699,France,Female,39,1,0.0,2,0,0,93826.63,0,0.9468
# 850,Spain,Female,43,2,125510.82,1,1,1,79084.1,0,0.9484
